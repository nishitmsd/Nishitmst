# %% [markdown]
# <a href="https://colab.research.google.com/github/nishitmsd/Nishitmst/blob/main/HW01_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Nishit Patel napn9w@umsystem.edu
#
# Course: CS 5402
#
# Assignment: Programming Assignment 01
#
# Repository:
#
# Date: 2022-06-13

# %% [markdown]
# #Concept Description:
#
# Determine the difference between data mining and machine learing. What languages used in them?

# %%
#imported for data management dataframe
import pandas as pd 

#imported to create word clouds.  
#This package need part of anaconda and need to installed conda install -c conda-forge wordcloud
from wordcloud import WordCloud

#imported to allow fot the display of word clouds 
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Data Collection:
#
# Google the search phrase "what is data mining" and "what is machine learning". For each search phrase, the first 14 results pages are browsed and search fir a block of text that starts with something aking to "Data mining is..." or "Machine learning is...". The text blocks are recoreded as examples along with the link of the page, the search phrase, and the date the results were pulled abd name of site the results were from.
#
# The results for each search phrase are saved in one comma separated file per each search phrase.

# %% [markdown]
# #Example Description:
# Category-
# The search phrase that is searched. The catagory is a label
#
# PullDate-
# The date the search was obtained. the pull date is a date.
#
# Source-
# The name of the site that was retured as result. The source is a character string.
#
# Link-
# The link that was retured as a result. The link is a character string.
#
# Text-
# The text block that is was selected from the page that was returened as a result of the search. The text is a character string.

# %% [markdown]
# #Data Imprt and Warngling:
# The reults of each search is read from the respective comma separated values file(cvs) into separate dataframe. Carefully,  attention is paid to make sure the data is read in as character strings.

# %%
df_mining = pd.read_csv(r"/content/drive/MyDrive/data-mining.csv") #filepath Access
df_learning = pd.read_csv(r"/content/drive/MyDrive/machine-learning.csv") #filepath Access
df_mining
df_learning
# Out:
#              Category   Pull Date                Source  \
# 0   Machine Learning   13-06-2022  Towards Data Science
# 1   Machine Learning   13-06-2022                   IBM
# 2   Machine Learning   13-06-2022             EXPERT.AI
# 3   Machine Learning   13-06-2022                   SAS
# 4   Machine Learning   13-06-2022             Wikipedia
# 5   Machine Learning   13-06-2022                   MIT
# 6   Machine Learning   13-06-2022              Coursera
# 7   Machine Learning   13-06-2022             Microsoft
# 8   Machine Learning   13-06-2022          Geekforgeeks
# 9   Machine Learning   13-06-2022                MatLab
# 10  Machine Learning   13-06-2022                Oracle
# 11  Machine Learning   13-06-2022         Royal Society
# 12  Machine Learning   13-06-2022          Investopedia
# 13  Machine Learning   13-06-2022       MIT Tech Review
#
#                                                  Link  \
# 0   https://towardsdatascience.com/how-to-learn-ma...
# 1    https://www.ibm.com/cloud/learn/machine-learning
# 2   https://www.expert.ai/blog/machine-learning-de...
# 3   https://www.sas.com/en_us/insights/analytics/m...
# 4      https://en.wikipedia.org/wiki/Machine_learning
# 5   https://mitsloan.mit.edu/ideas-made-to-matter/...
# 6   https://www.coursera.org/lecture/machine-learn...
# 7   https://azure.microsoft.com/en-us/overview/wha...
# 8     https://www.geeksforgeeks.org/machine-learning/
# 9   https://www.mathworks.com/discovery/machine-le...
# 10  https://www.oracle.com/data-science/machine-le...
# 11  https://royalsociety.org/topics-policy/project...
# 12  https://www.investopedia.com/terms/m/machine-l...
# 13  https://www.technologyreview.com/2018/11/17/10...
#
#                                                  Text
# 0   the field of study that gives computers the ab...
# 1   Machine learning is a branch of artificial int...
# 2   Machine learning is an application of AI that ...
# 3   Machine learning is a method of data analysis ...
# 4   Machine learning (ML) is a field of inquiry de...
# 5   Machine learning is behind chatbots and predic...
# 6   Machine learning is the science of getting com...
# 7   Machine learning (ML) is the process of using ...
# 8   Machine Learning is the field of study that gi...
# 9   Machine learning is a data analytics technique...
# 10  Machine learning (ML) is the subset of artific...
# 11  Machine learning is used in internet search en...
# 12  Machine learning is the concept that a compute...
# 13  Machine learning is the process that powers ma...

# %% [markdown]
# The text blocks from the results of a search is concatenated together into one large text string. The blank text were loaded in as "NA". We convert them back to empty text string beacuse wordcloud will not accept non-string data.

# %%
#convert all Text attribute values ti test strings 
str_mining = ''.join(list(df_mining['Text']))

#Replace any Na values with a blank text string 
str_learning = ''.join(list(df_learning['Text'].fillna('')))

# %% [markdown]
# #Exploratory Data Analysis:
#  Not applicable.
#
# #Mining or Analytics:
# Word cloud are generated for each search result

# %%
from wordcloud import WordCloud
wordcloud_mining = WordCloud().generate(str_mining)
wordcloud_learning = WordCloud().generate(str_learning)

# %% [markdown]
# # New Section

# %%
plt.figure(figsize=(15,8))
plt.axis('off')
plt.imshow(wordcloud_mining, interpolation = 'bilinear')

# %%
plt.figure(figsize=(15,8))
plt.axis('off')
plt.imshow(wordcloud_learning, interpolation = 'bilinear')

# %% [markdown]
# #Evalution:
#  Not applicable
#
# #Results:
# The language used for data mining is simliar, but different than machine learning.
#
# As we know, Data mining is the process of extracting and discovering patterns from large dataset.
# Machine learning is
#
# The wordcloud generated for data mining has words like pattern, data, process, infromation and similarly to machine learning words like search, model, learn, systems, subset, etc. Therefore from a given set of raw data we can generate wordcloud in order to get meaninggul information.

# %% [markdown]
# #Reference:
# 1. Lecture Note - CS5402 Intro to Data Mining.pptx
# 2. Anaconda cloud. (2019). Wordcloud. Retrieved(2020, january 23) from https://anaconda.org/conda-forge/wordcloud
